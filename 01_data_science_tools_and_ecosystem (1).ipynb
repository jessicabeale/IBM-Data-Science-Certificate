# %% [markdown]
# # Data Science Tools and Ecosystems

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1) python
# 2) SQL
# 3) C++
# 4) Java
# 5) R

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1) TensorFlow
# 2) NumPy
# 3) SciPy
# 4) Pandas
# 5) Matplotlib
# 6) Keras
# 7) SciKit-Learn
# 8) PyTorch

# %% [markdown]
# |Data Science Tools|
# |---|
# |SAS|
# |Apache Hadoop|
# |TensorFlow|

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
#this is a common arithmetic example to multiply and add integers
(3*4)+5
# Out:
# 17

# %%
# this will convert 200 minutes to hours by dividing by 60
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# __Objectives__
# * List popular languages for Data Science
# * List popular libaries for Data Science
# * List of well known Data Science Tools
# * How to provide comments in the cell

# %% [markdown]
# ### Note
# Of the languages and tools above, Python and SQL are the ones I expect to lean on most going forward — both come up constantly in security tooling (log parsing, SIEM queries, automation), which is the direction I'm ultimately headed in.

# %%
# a slightly less trivial expression than the course example
seconds_in_a_week = 7 * 24 * 60 * 60
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# ## Author
# Jessica Beale
